# %% [markdown]
# # **Healthcare Data Cleaning Imputation**

# %% [markdown]
# ### **Date/Time Conversion**

# %%
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer

# %%
# Read the patienthistory.csv and store it at df_patient dataframe
df_patient = pd.read_csv('PatientHistory.csv')

# %%
# Convert DateOfVisit and LastPaymentDate to datetime objects
df_patient['DateOfVisit'] = pd.to_datetime(df_patient['DateOfVisit'])
df_patient['LastPaymentDate'] = pd.to_datetime(df_patient['LastPaymentDate'])

# %%
# Convert BillAmount and FollowUpDays to float type
df_patient['BillAmount'] = pd.to_numeric(df_patient['BillAmount'], errors='coerce')
df_patient['FollowUpDays'] = pd.to_numeric(df_patient['FollowUpDays'], errors='coerce')

# %%
# Convert Doctor empty strings into np.nan
df_patient['Doctor'] = df_patient['Doctor'].replace('', np.nan)

# %%
# Display the df_patient
df_patient
# Out:
#    PatientID    PatientName DateOfVisit            Diagnosis  \
# 0       P001       John Doe  2023-01-15          Common Cold
# 1       P002     Jane Smith  2023-02-01             Migraine
# 2       P003    Alice Brown  2023-02-10       Sprained Ankle
# 3       P004      Bob White  2023-03-05   Seasonal Allergies
# 4       P005  Charlie Green  2023-03-20         Strep Throat
# 5       P006   Diana Prince  2023-04-01     Routine Check-up
# 6       P007   Edward Stark  2023-04-12            Back Pain
# 7       P008    Fiona Glenn  2023-05-03             Insomnia
# 8       P009    George King  2023-05-18                  Flu
# 9       P010   Hannah Scott  2023-06-01           Dermatitis
# 10      P011    Ivan Petrov  2023-06-10        Dental Cavity
# 11      P012     Julia Chen  2023-07-05      Sinus Infection
# 12      P013       Kyle Ren  2023-07-20           Broken Arm
# 13      P014     Laura Bell  2023-08-01              Anxiety
# 14      P015      Mike Ross  2023-08-15       Food Poisoning
# 15      P016     Nancy Drew  2023-09-01        Ear Infection
# 16      P017    Oscar Wilde  2023-09-10            Knee Pain
# 17      P018     Pamela Bee  2023-10-02         Vision Check
# 18      P019   Quinn Fabray  2023-10-18          Sore Throat
# 19      P020   Rachel Green  2023-11-05         Allergy Test
# 20      P021   Steve Rogers  2023-11-20        Fractured Rib
# 21      P022   Tina Belcher  2023-12-01          Vaccination
# 22      P023    Uma Thurman  2023-12-15  High Blood Pressure
# 23      P024   Victor Stone  2024-01-05           Minor Burn
# 24      P025  Wendy Darling  2024-01-20      Dental Cleaning
# 25      P001       John Doe  2023-01-15          Common Cold
# 26      P005  Charlie Green  2023-03-20         Strep Throat
# 27      P010   Hannah Scott  2023-06-01           Dermatitis
# 28      P013       Kyle Ren  2023-07-20           Broken Arm
# 29      P018     Pamela Bee  2023-10-02         Vision Check
#
#                   Treatment      Doctor  BillAmount   PaymentStatus  \
# 0           Rest and Fluids   Dr. Smith       50.00            Paid
# 1                Medication   Dr. Jones      120.50            Paid
# 2          Physical Therapy   Dr. Davis      300.75         Pending
# 3            Antihistamines   Dr. Smith       75.00            Paid
# 4               Antibiotics   Dr. Jones       90.25            Paid
# 5           Preventive Care   Dr. Evans       80.00            Paid
# 6   Chiropractic Adjustment  Dr. Wilson      450.00  Partially Paid
# 7               Sleep Study    Dr. Reed      600.00         Pending
# 8      Antiviral Medication   Dr. Smith      110.00            Paid
# 9             Topical Cream  Dr. Miller         NaN            Paid
# 10                  Filling         NaN      200.00         Pending
# 11              Antibiotics   Dr. Evans       95.00            Paid
# 12         Cast Application   Dr. Davis      800.00  Partially Paid
# 13          Therapy Session    Dr. Reed      100.00            Paid
# 14              Observation   Dr. Jones       60.00            Paid
# 15                Ear Drops   Dr. Smith       70.00            Paid
# 16                      MRI  Dr. Wilson      750.00         Pending
# 17              New Glasses  Dr. Miller      250.00            Paid
# 18                     Rest   Dr. Evans         NaN            Paid
# 19          Skin Prick Test   Dr. Smith      180.00         Pending
# 20          Pain Management   Dr. Davis      550.00  Partially Paid
# 21                 Flu Shot   Dr. Jones       30.00            Paid
# 22    Medication Adjustment  Dr. Miller      100.00            Paid
# 23               Burn Cream   Dr. Evans       55.00            Paid
# 24      Routine Dental Care   Dr. Baker      100.00            Paid
# 25          Rest and Fluids   Dr. Smith       50.00            Paid
# 26              Antibiotics   Dr. Jones       90.25            Paid
# 27            Topical Cream  Dr. Miller         NaN            Paid
# 28         Cast Application   Dr. Davis      800.00  Partially Paid
# 29              New Glasses  Dr. Miller      250.00            Paid
#
#    LastPaymentDate  FollowUpDays
# 0       2023-01-15           7.0
# 1       2023-02-05          14.0
# 2              NaN          21.0
# 3       2023-03-05           7.0
# 4       2023-03-22           5.0
# 5       2023-04-01          30.0
# 6       2023-04-20           NaN
# 7              NaN          90.0
# 8       2023-05-18           7.0
# 9       2023-06-02          10.0
# 10             NaN           NaN
# 11      2023-07-06           7.0
# 12      2023-07-25          45.0
# 13      2023-08-01          60.0
# 14      2023-08-15           3.0
# 15      2023-09-01           7.0
# 16             NaN           NaN
# 17      2023-10-03         365.0
# 18      2023-10-18           3.0
# 19             NaN           NaN
# 20      2023-11-25          90.0
# 21      2023-12-01         365.0
# 22      2023-12-16          30.0
# 23      2024-01-05           7.0
# 24      2024-01-20         180.0
# 25      2023-01-15           7.0
# 26      2023-03-22           5.0
# 27      2023-06-02          10.0
# 28      2023-07-25          45.0
# 29      2023-10-03         365.0

# %%
# Show df_patient info to check the conversion
df_patient.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PatientID        30 non-null     object
#  1   PatientName      30 non-null     object
#  2   DateOfVisit      30 non-null     object
#  3   Diagnosis        30 non-null     object
#  4   Treatment        30 non-null     object
#  5   Doctor           29 non-null     object
#  6   BillAmount       27 non-null     float64
#  7   PaymentStatus    30 non-null     object
#  8   LastPaymentDate  25 non-null     object
#  9   FollowUpDays     26 non-null     float64
# dtypes: float64(2), object(8)
# memory usage: 2.5+ KB

# %%
# Show the total missing values
df_patient.isnull().sum()
# Out:
# PatientID          0
# PatientName        0
# DateOfVisit        0
# Diagnosis          0
# Treatment          0
# Doctor             1
# BillAmount         3
# PaymentStatus      0
# LastPaymentDate    5
# FollowUpDays       4
# dtype: int64

# %% [markdown]
# ### **Handle Duplicates**

# %%
# Check first the total number of duplicates
duplicates_count = df_patient.duplicated().sum()
print(f"Number of duplicate rows: {duplicates_count}")
# Out:
# Number of duplicate rows: 5

# %%
# Drop duplicate rows
# Store to df_patient_no_duplicates
df_patient_no_duplicates = df_patient.drop_duplicates()

# %%
# Print df_patient_no_duplicates
df_patient_no_duplicates
# Out:
#    PatientID    PatientName DateOfVisit            Diagnosis  \
# 0       P001       John Doe  2023-01-15          Common Cold
# 1       P002     Jane Smith  2023-02-01             Migraine
# 2       P003    Alice Brown  2023-02-10       Sprained Ankle
# 3       P004      Bob White  2023-03-05   Seasonal Allergies
# 4       P005  Charlie Green  2023-03-20         Strep Throat
# 5       P006   Diana Prince  2023-04-01     Routine Check-up
# 6       P007   Edward Stark  2023-04-12            Back Pain
# 7       P008    Fiona Glenn  2023-05-03             Insomnia
# 8       P009    George King  2023-05-18                  Flu
# 9       P010   Hannah Scott  2023-06-01           Dermatitis
# 10      P011    Ivan Petrov  2023-06-10        Dental Cavity
# 11      P012     Julia Chen  2023-07-05      Sinus Infection
# 12      P013       Kyle Ren  2023-07-20           Broken Arm
# 13      P014     Laura Bell  2023-08-01              Anxiety
# 14      P015      Mike Ross  2023-08-15       Food Poisoning
# 15      P016     Nancy Drew  2023-09-01        Ear Infection
# 16      P017    Oscar Wilde  2023-09-10            Knee Pain
# 17      P018     Pamela Bee  2023-10-02         Vision Check
# 18      P019   Quinn Fabray  2023-10-18          Sore Throat
# 19      P020   Rachel Green  2023-11-05         Allergy Test
# 20      P021   Steve Rogers  2023-11-20        Fractured Rib
# 21      P022   Tina Belcher  2023-12-01          Vaccination
# 22      P023    Uma Thurman  2023-12-15  High Blood Pressure
# 23      P024   Victor Stone  2024-01-05           Minor Burn
# 24      P025  Wendy Darling  2024-01-20      Dental Cleaning
#
#                   Treatment      Doctor  BillAmount   PaymentStatus  \
# 0           Rest and Fluids   Dr. Smith       50.00            Paid
# 1                Medication   Dr. Jones      120.50            Paid
# 2          Physical Therapy   Dr. Davis      300.75         Pending
# 3            Antihistamines   Dr. Smith       75.00            Paid
# 4               Antibiotics   Dr. Jones       90.25            Paid
# 5           Preventive Care   Dr. Evans       80.00            Paid
# 6   Chiropractic Adjustment  Dr. Wilson      450.00  Partially Paid
# 7               Sleep Study    Dr. Reed      600.00         Pending
# 8      Antiviral Medication   Dr. Smith      110.00            Paid
# 9             Topical Cream  Dr. Miller         NaN            Paid
# 10                  Filling         NaN      200.00         Pending
# 11              Antibiotics   Dr. Evans       95.00            Paid
# 12         Cast Application   Dr. Davis      800.00  Partially Paid
# 13          Therapy Session    Dr. Reed      100.00            Paid
# 14              Observation   Dr. Jones       60.00            Paid
# 15                Ear Drops   Dr. Smith       70.00            Paid
# 16                      MRI  Dr. Wilson      750.00         Pending
# 17              New Glasses  Dr. Miller      250.00            Paid
# 18                     Rest   Dr. Evans         NaN            Paid
# 19          Skin Prick Test   Dr. Smith      180.00         Pending
# 20          Pain Management   Dr. Davis      550.00  Partially Paid
# 21                 Flu Shot   Dr. Jones       30.00            Paid
# 22    Medication Adjustment  Dr. Miller      100.00            Paid
# 23               Burn Cream   Dr. Evans       55.00            Paid
# 24      Routine Dental Care   Dr. Baker      100.00            Paid
#
#    LastPaymentDate  FollowUpDays
# 0       2023-01-15           7.0
# 1       2023-02-05          14.0
# 2              NaN          21.0
# 3       2023-03-05           7.0
# 4       2023-03-22           5.0
# 5       2023-04-01          30.0
# 6       2023-04-20           NaN
# 7              NaN          90.0
# 8       2023-05-18           7.0
# 9       2023-06-02          10.0
# 10             NaN           NaN
# 11      2023-07-06           7.0
# 12      2023-07-25          45.0
# 13      2023-08-01          60.0
# 14      2023-08-15           3.0
# 15      2023-09-01           7.0
# 16             NaN           NaN
# 17      2023-10-03         365.0
# 18      2023-10-18           3.0
# 19             NaN           NaN
# 20      2023-11-25          90.0
# 21      2023-12-01         365.0
# 22      2023-12-16          30.0
# 23      2024-01-05           7.0
# 24      2024-01-20         180.0

# %%
# Check number of missing values in df_patient_no_duplicates
df_patient_no_duplicates.isnull().sum()
# Out:
# PatientID          0
# PatientName        0
# DateOfVisit        0
# Diagnosis          0
# Treatment          0
# Doctor             1
# BillAmount         2
# PaymentStatus      0
# LastPaymentDate    5
# FollowUpDays       4
# dtype: int64

# %% [markdown]
# ### **Median Imputation**

# %%
# Copy df_patient_no_duplicates to df_median
df_median = df_patient_no_duplicates.copy()

# %%
# Calculate median of BillAmount stored at median_bill_amount
median_bill_amount = df_median['BillAmount'].median()
print(f"Median BillAmount: {median_bill_amount}")
# Out:
# Median BillAmount: 100.0

# %%
# Fill the missing BillAmount with median_bill_amount in df_median
df_median['BillAmount'] = df_median['BillAmount'].fillna(median_bill_amount)

# %%
# Print df_median
df_median
# Out:
#    PatientID    PatientName DateOfVisit            Diagnosis  \
# 0       P001       John Doe  2023-01-15          Common Cold
# 1       P002     Jane Smith  2023-02-01             Migraine
# 2       P003    Alice Brown  2023-02-10       Sprained Ankle
# 3       P004      Bob White  2023-03-05   Seasonal Allergies
# 4       P005  Charlie Green  2023-03-20         Strep Throat
# 5       P006   Diana Prince  2023-04-01     Routine Check-up
# 6       P007   Edward Stark  2023-04-12            Back Pain
# 7       P008    Fiona Glenn  2023-05-03             Insomnia
# 8       P009    George King  2023-05-18                  Flu
# 9       P010   Hannah Scott  2023-06-01           Dermatitis
# 10      P011    Ivan Petrov  2023-06-10        Dental Cavity
# 11      P012     Julia Chen  2023-07-05      Sinus Infection
# 12      P013       Kyle Ren  2023-07-20           Broken Arm
# 13      P014     Laura Bell  2023-08-01              Anxiety
# 14      P015      Mike Ross  2023-08-15       Food Poisoning
# 15      P016     Nancy Drew  2023-09-01        Ear Infection
# 16      P017    Oscar Wilde  2023-09-10            Knee Pain
# 17      P018     Pamela Bee  2023-10-02         Vision Check
# 18      P019   Quinn Fabray  2023-10-18          Sore Throat
# 19      P020   Rachel Green  2023-11-05         Allergy Test
# 20      P021   Steve Rogers  2023-11-20        Fractured Rib
# 21      P022   Tina Belcher  2023-12-01          Vaccination
# 22      P023    Uma Thurman  2023-12-15  High Blood Pressure
# 23      P024   Victor Stone  2024-01-05           Minor Burn
# 24      P025  Wendy Darling  2024-01-20      Dental Cleaning
#
#                   Treatment      Doctor  BillAmount   PaymentStatus  \
# 0           Rest and Fluids   Dr. Smith       50.00            Paid
# 1                Medication   Dr. Jones      120.50            Paid
# 2          Physical Therapy   Dr. Davis      300.75         Pending
# 3            Antihistamines   Dr. Smith       75.00            Paid
# 4               Antibiotics   Dr. Jones       90.25            Paid
# 5           Preventive Care   Dr. Evans       80.00            Paid
# 6   Chiropractic Adjustment  Dr. Wilson      450.00  Partially Paid
# 7               Sleep Study    Dr. Reed      600.00         Pending
# 8      Antiviral Medication   Dr. Smith      110.00            Paid
# 9             Topical Cream  Dr. Miller      100.00            Paid
# 10                  Filling         NaN      200.00         Pending
# 11              Antibiotics   Dr. Evans       95.00            Paid
# 12         Cast Application   Dr. Davis      800.00  Partially Paid
# 13          Therapy Session    Dr. Reed      100.00            Paid
# 14              Observation   Dr. Jones       60.00            Paid
# 15                Ear Drops   Dr. Smith       70.00            Paid
# 16                      MRI  Dr. Wilson      750.00         Pending
# 17              New Glasses  Dr. Miller      250.00            Paid
# 18                     Rest   Dr. Evans      100.00            Paid
# 19          Skin Prick Test   Dr. Smith      180.00         Pending
# 20          Pain Management   Dr. Davis      550.00  Partially Paid
# 21                 Flu Shot   Dr. Jones       30.00            Paid
# 22    Medication Adjustment  Dr. Miller      100.00            Paid
# 23               Burn Cream   Dr. Evans       55.00            Paid
# 24      Routine Dental Care   Dr. Baker      100.00            Paid
#
#    LastPaymentDate  FollowUpDays
# 0       2023-01-15           7.0
# 1       2023-02-05          14.0
# 2              NaN          21.0
# 3       2023-03-05           7.0
# 4       2023-03-22           5.0
# 5       2023-04-01          30.0
# 6       2023-04-20           NaN
# 7              NaN          90.0
# 8       2023-05-18           7.0
# 9       2023-06-02          10.0
# 10             NaN           NaN
# 11      2023-07-06           7.0
# 12      2023-07-25          45.0
# 13      2023-08-01          60.0
# 14      2023-08-15           3.0
# 15      2023-09-01           7.0
# 16             NaN           NaN
# 17      2023-10-03         365.0
# 18      2023-10-18           3.0
# 19             NaN           NaN
# 20      2023-11-25          90.0
# 21      2023-12-01         365.0
# 22      2023-12-16          30.0
# 23      2024-01-05           7.0
# 24      2024-01-20         180.0

# %% [markdown]
# ### **Mode Imputation**

# %%
# Copy df_median to df_mode
df_mode = df_median.copy()

# %%
# Calculate mode of 'Doctor' and store it at mode_doctor
mode_doctor = df_mode['Doctor'].mode()[0]
print(f"Mode Doctor: {mode_doctor}")
# Out:
# Mode Doctor: Dr. Smith

# %%
# Fill missing Doctor with mode_doctor
df_mode['Doctor'] = df_mode['Doctor'].fillna(mode_doctor)

# %%
# Print df_mode
df_mode
# Out:
#    PatientID    PatientName DateOfVisit            Diagnosis  \
# 0       P001       John Doe  2023-01-15          Common Cold
# 6       2023-04-20           NaN
# 7              NaN          90.0
# 8       2023-05-18           7.0
# 9       2023-06-02          10.0
# 10             NaN           NaN
# 11      2023-07-06           7.0
# 12      2023-07-25          45.0
# 13      2023-08-01          60.0
# 14      2023-08-15           3.0
# 15      2023-09-01           7.0
# 16             NaN           NaN
# 17      2023-10-03         365.0
# 18      2023-10-18           3.0
# 19             NaN           NaN
# 20      2023-11-25          90.0
# 21      2023-12-01         365.0
# 22      2023-12-16          30.0
# 23      2024-01-05           7.0
# 24      2024-01-20         180.0

# %% [markdown]
# ### **K-Nearest Neighbor**

# %%
# Copy columns 'BillAmount', 'FollowUpDays' stored at columns_for_knn
columns_for_knn = ['BillAmount', 'FollowUpDays']

# %%
# Copy df_mode with column_for_knn to df_knn
df_knn = df_mode[columns_for_knn].copy()

# %%
# Import KNNImputer from sklearn.impute (already imported above)
# Import numpy with alias np (already imported above)
# Initialize KNNImputer with imputer variable. Use n_neighbors=5
imputer = KNNImputer(n_neighbors=5)

# %%
# Store to imputed_data after the fit and transform of df_knn
imputed_data = imputer.fit_transform(df_knn)

# %%
# Store in df_knn_imputed the array imputed_data after conversion to dataframe
# Make sure you retain the original index to map back correctly
df_knn_imputed = pd.DataFrame(imputed_data, columns=columns_for_knn, index=df_knn.index)
df_knn_imputed
# Out:
#     BillAmount  FollowUpDays
# 0        50.00           7.0
# 1       120.50          14.0
# 2       300.75          21.0
# 3        75.00           7.0
# 4        90.25           5.0
# 5        80.00          30.0
# 6       450.00         116.0
# 7       600.00          90.0
# 8       110.00           7.0
# 9       100.00          10.0
# 10      200.00          91.2
# 11       95.00           7.0
# 12      800.00          45.0
# 13      100.00          60.0
# 14       60.00           3.0
# 15       70.00           7.0
# 16      750.00         122.2
# 17      250.00         365.0
# 18      100.00           3.0
# 19      180.00          91.2
# 20      550.00          90.0
# 21       30.00         365.0
# 22      100.00          30.0
# 23       55.00           7.0
# 24      100.00         180.0

# %%
# Print missing values for df_knn_imputed
df_knn_imputed.isnull().sum()
# Out:
# BillAmount      0
# FollowUpDays    0
# dtype: int64

# %%
# Print the cleaned data
df_knn_imputed = df_mode.copy()

df_knn_imputed[['BillAmount', 'FollowUpDays']] = pd.DataFrame(imputed_data, columns=['BillAmount', 'FollowUpDays'], index=df_knn_imputed.index)
df_knn_imputed
# Out:
#    PatientID    PatientName DateOfVisit            Diagnosis  \
# 0       P001       John Doe  2023-01-15          Common Cold
# 1       P002     Jane Smith  2023-02-01             Migraine
# 2       P003    Alice Brown  2023-02-10       Sprained Ankle
# 3       P004      Bob White  2023-03-05   Seasonal Allergies
# 4       P005  Charlie Green  2023-03-20         Strep Throat
# 5       P006   Diana Prince  2023-04-01     Routine Check-up
# 6       P007   Edward Stark  2023-04-12            Back Pain
# 7       P008    Fiona Glenn  2023-05-03             Insomnia
# 8       P009    George King  2023-05-18                  Flu
# 9       P010   Hannah Scott  2023-06-01           Dermatitis
# 10      P011    Ivan Petrov  2023-06-10        Dental Cavity
